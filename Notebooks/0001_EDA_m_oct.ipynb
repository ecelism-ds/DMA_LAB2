# %% [markdown]
# # **Trabajo Final - Laboratorio II**
#
# *Integrantes:*
# * Celis Mendoza, Elemir
# * Dellatore, Andrés
# * Forconi, Gerónimo
# * Lignini, Maira
# * Palomeque, Claudia
# * Postiglione, Sebastián

# %% [markdown]
# ## 1. Objetivo
#
# Predecir la velocidad de adopción de una mascota.
#
# En este caso, la velocidad de adopción se determina por la rapidez con la que todas las mascotas del grupo son adoptadas.
#
# Dentro de los datos, observamos que se incluye información de texto, tabulares y datos de imágenes.

# %% [markdown]
# ## 2. Información disponible
#
# ### Variables dataset inicial
# * PetID - Identificador único en forma de hash del perfil de la mascota
# * Tipo - Tipo de animal (1 = Perro, 2 = Gato)
# * Nombre - Nombre de la mascota (Vacío si no tiene nombre)
# * Edad - Edad de la mascota cuando se registró, en meses
# * Raza1 - Raza principal de la mascota
# * Raza2 - Raza secundaria de la mascota, si es de raza mixta
# * Género - Género de la mascota (1 = Macho, 2 = Hembra, 3 = Mixto, si el perfil representa a un grupo de mascotas)
# * Color1 - Color 1 de la mascota
# * Color2 - Color 2 de la mascota
# * Color3 - Color 3 de la mascota
# * Madurez - Tamaño en la madurez (1 = Pequeño, 2 = Mediano, 3 = Grande, 4 = Extra Grande, 0 = No Especificado)
# * Longitud de Pelaje - Longitud del pelaje (1 = Corto, 2 = Mediano, 3 = Largo, 0 = No Especificado)
# * Vacunado - Si la mascota ha sido vacunada (1 = Sí, 2 = No, 3 = No Estoy Seguro)
# * Desparasitado - Si la mascota ha sido desparasitada (1 = Sí, 2 = No, 3 = No Estoy Seguro)
# * Esterilizado - Si la mascota ha sido esterilizada / castrada (1 = Sí, 2 = No, 3 = No Estoy Seguro)
# * Salud - Condición de salud (1 = Saludable, 2 = Lesión Menor, 3 = Lesión Grave, 0 = No Especificado)
# * Cantidad - Número de mascotas representadas en el perfil
# * Tarifa - Tarifa de adopción (0 = Gratis)
# * Estado - Ubicación en el estado de Malasia
# * IDRescatador - Identificador único en forma de hash del rescatador
# * CantidadVideos - Total de videos subidos para esta mascota
# * CantidadFotos - Total de fotos subidas para esta mascota
# * Descripción - Descripción escrita del perfil de esta mascota. El idioma principal utilizado es el inglés, con algunas descripciones en malayo o chino.
#
# ### Variable Target
# *AdoptionSpeed* - Velocidad de adopción (categorizada).
#
# 0 - La mascota fue adoptada el mismo día en que fue listada.
#
# 1 - La mascota fue adoptada entre 1 y 7 días (1ra semana) después de ser listada.
#
# 2 - La mascota fue adoptada entre 8 y 30 días (1er mes) después de ser listada.
#
# 3 - La mascota fue adoptada entre 31 y 90 días (2do y 3er mes) después de ser listada.
#
# 4 - No hubo adopción después de 100 días de ser listada. (En este conjunto de datos, no hay mascotas que hayan esperado entre 90 y 100 días).
#
# ### Información adicional
# * Metadatos de las imágenes
# * Datos de Sentimiento

# %% [markdown]
# # 3. Análisis

# %% [markdown]
# ## Etapa 1 : Utilizo sólo la información disponible en Train

# %%
# 1. Importo librerias

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

#import cv2 #Para cargar/mostrar/procesar imagenes
import json
import glob #Para listar los archivos en una carpeta

# Librerias propias (contienen los modelos)
#import model_metadata
#mport model_sentiment

# cargar el resto de las librerias necesarias acá
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\CLAU 2023_2\AUSTRAL\LABO 2\KAGGLE\0001_EDA_m.ipynb Celda 6 line 3
#       <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # 1. Importo librerias
# ----> <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#Código Auxiliar!
#Para borrar la cache de las librerias propias
#import importlib
#importlib.reload(model_sentiment)
#importlib.reload(model_metadata)

# %%
#2. Lectura Dataset inicial 
train_data = pd.read_csv('../data/train/train.csv', index_col='PetID') # este dataset es el train no el total. El tratamiento posterior debe replicarse en test

print (train_data.head(10))
# Info del dataset

train_data.info ()
#14.993 registros
#23 variables

# Se presentan variables como númericas cuando en realidad el número en cuestión es una categoría.
# Hay que transformarla
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\CLAU 2023_2\AUSTRAL\LABO 2\KAGGLE\0001_EDA_m.ipynb Celda 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> #2. Lectura Dataset inicial
# ----> <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> train_data = pd.read_csv('../data/train/train.csv', index_col='PetID') # este dataset es el train no el total. El tratamiento posterior debe replicarse en test
#       <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> print (train_data.head(10))
#       <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> # Info del dataset
#
# ...

# %%
#3. Transformación de los datos

train_data['Type'] = train_data['Type'].astype('category')
train_data['Breed1'] = train_data['Breed1'].astype('category')
train_data['Breed2'] = train_data['Breed2'].astype('category')
train_data['Gender'] = train_data['Gender'].astype('category')
train_data['health1'] = train_data['health1'].astype('category')
train_data['health2'] = train_data['health2'].astype('category')
train_data['health3'] = train_data['health3'].astype('category')
train_data['MaturitySize'] = train_data['MaturitySize'].astype('category')
train_data['FurLength'] = train_data['FurLength'].astype('category')
train_data['Vaccinated'] = train_data['Vaccinated'].astype('category')
train_data['Dewormed'] = train_data['Dewormed'].astype('category')
train_data['Sterilized'] = train_data['Sterilized'].astype('category')
train_data['Health'] = train_data['Health'].astype('category')
train_data['State'] = train_data['State'].astype('category')
train_data['AdoptionSpeed'] = train_data['AdoptionSpeed'].astype('category')
#train_data.info()--> ok
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\CLAU 2023_2\AUSTRAL\LABO 2\KAGGLE\0001_EDA_m.ipynb Celda 9 line 3
#       <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> #3. Transformación de los datos
# ----> <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> train_data['Type'] = train_data['Type'].astype('category')
#       <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> train_data['Breed1'] = train_data['Breed1'].astype('category')
#       <a href='vscode-notebook-cell:/c%3A/CLAU%202023_2/AUSTRAL/LABO%202/KAGGLE/0001_EDA_m.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> train_data['Breed2'] = train_data['Breed2'].astype('category')
#
# ...

# %%
#4. 
# a. Estadísticas descriptivas (continuas) y tablas de frecuencias (categóricas)

# Separar las columnas continuas y categóricas
#columnas_continuas = train_data.select_dtypes(include=['int64', 'float64']).columns.tolist()
#columnas_categoricas = train_data.select_dtypes(include=['category']).columns.tolist()

# Estadísticas descriptivas para variables continuas
#descripcion_continuas = train_data[columnas_continuas].describe()

# Frecuencias por categorías para variables categóricas
# frecuencias_categoricas = {}
# for columna in columnas_categoricas:
#     frecuencias_categoricas[columna] = train_data[columna].value_counts()

# # Imprimir las estadísticas descriptivas para variables continuas
# print("Estadísticas descriptivas para variables continuas:")
# print(descripcion_continuas)
# print()

# # Imprimir las frecuencias por categorías para variables categóricas
# for columna, frecuencias in frecuencias_categoricas.items():
#     print(f"Frecuencias para {columna}:")
#     print(frecuencias)
#     print()

# %%
# Divido el dataset para poder trabajar con la librería profiling
vbles_continuas = train_data.select_dtypes(include=['float64', 'int64'])
vbles_categoricas = train_data.select_dtypes(include=['category']) 

# Armo sub-dataset de vbles categóricas para analizar
vble_target = vbles_categoricas.filter(['AdoptionSpeed'], axis=1)
vbles_cat_gral = vbles_categoricas.filter(['Type', 'State'], axis=1)
vbles_cat_salud = vbles_categoricas.filter(['Vaccinated', 'Health', 'Sterilized', 'Dewormed' ], axis=1)
vbles_cat_fisicas1 = vbles_categoricas.filter(['Breed1', 'Breed2', 'health1', 'health2', 'health3'], axis=1)
vbles_cat_fisicas2 = vbles_categoricas.filter(['Gender', 'MaturitySize', 'FurLength'], axis=1)


#print(vbles_continuas)
#print(vbles_cat_gral)
#print(vbles_cat_salud)
#print(vbles_cat_fisicas1)
#print(vbles_cat_fisicas2)

# %%
# 3. EDA

from ydata_profiling import ProfileReport

EDA_cont = ProfileReport(vbles_continuas)
EDA_cont.to_file("EDA_continuas.html")



EDA_target = ProfileReport(vble_target)
EDA_target.to_file("EDA_target.html")

EDA_cat_gral = ProfileReport(vbles_cat_gral)
EDA_cat_gral.to_file("EDA_cat_gral.html")

EDA_cat_salud = ProfileReport(vbles_cat_salud)
EDA_cat_salud.to_file("EDA_cat_salud.html")

EDA_cat_fisicas1 = ProfileReport(vbles_cat_fisicas1)
EDA_cat_fisicas1.to_file("EDA_cat_fisicas1.html")

EDA_cat_fisicas2 = ProfileReport(vbles_cat_fisicas2)
EDA_cat_fisicas2.to_file("EDA_cat_fisicas2.html")

#del EDA_cont
#del EDA_cat_gral
#del EDA_cat_salud 
#del EDA_cat_fisicas1
#del EDA_cat_fisicas2
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Análisis exploratorio de los datos
#
# #### Análisis univariado
#
# El dataset no presenta valores faltantes.
# En relación al valor “cero”, observamos que es un valor posible para las variables del dataset, indicando la ausencia del atributo que se está midiendo.
#
# *Variables continuas*
#
# Edad
#
# En este conjunto de datos, se observa una considerable variabilidad en las edades de las mascotas registradas. El rango de edades abarca desde un mínimo de 0 meses hasta un máximo de 255 meses, lo que demuestra que se han incluido mascotas de todas las edades.
#
# La mediana de la edad es de 3 meses, lo que nos sugiere que la mitad de las mascotas en este conjunto de datos tienen menos de 3 meses, mientras que la otra mitad supera los 3 meses de edad.
#
# El rango intercuartil (RIQ) de 10 meses nos indica que el 50% intermedio de las edades se encuentra dentro de un intervalo de 2 meses a 12 meses, lo que nos proporciona una idea más detallada de la distribución de las edades que se registran en el dataset.
#
# La desviación estándar de 18.16 revela que existe una dispersión significativa en las edades registradas en el conjunto de datos, lo que significa que las edades varían considerablemente en torno a la media.
#
# Es importante destacar que en este conjunto de datos se presentan edades extremadamente atípicas, lo que podría requerir una revisión adicional y una posible depuración de datos.
#
# Cantidad (número de perfiles de las mascotas)
#
# Se evidencia que la mayoría de los valores se concentran en torno a un número bajo, ya que tanto la mediana como los cuartiles (Q1 y Q3) tienen un valor de 1. Además, el rango intercuartil (RIQ) es igual a 0, lo que indica que el 50% intermedio de los datos está en el mismo valor (1).
#
# Sin embargo, la variable muestra tambien una amplia dispersión en los datos. Esto sugiere que, aunque la mayoría de los perfiles de mascotas tienen una cantidad baja, existen algunos valores atípicos o extremos que contribuyen a esta dispersión. El coeficiente de variación (CV) es menor que 1, lo que indica una variabilidad relativamente baja en relación con la media.
#
# Tarifa de adopción
#
# Es evidente que una gran proporción de las adopciones se ofrecen de forma gratuita, ya que el valor mínimo, los percentiles 5, 25, 50 y 75, todos tienen un valor de 0. Esto indica que muchas mascotas se ofrecen sin costo alguno para los adoptantes.
#
# Sin embargo, se observa también una amplia variación en los datos, ya que el rango es de 3000, lo que significa que la tarifa máxima de adopción es 3000 veces mayor que la tarifa mínima. Esto se refleja en la alta desviación estándar y el coeficiente de variación (CV) mayor a 1, lo que indica una dispersión significativa en los datos en relación con la media.
# Por lo tanto, aunque la mayoría de las adopciones son gratuitas, existen casos excepcionales donde se cobra una tarifa sustancial por la adopción.
#
# Cantidad de videos
#
# La variable muestra que la gran mayoría de los perfiles de mascotas no incluyen videos, pero también señala una pequeña cantidad de casos excepcionales con un pequeño número de videos. La distribución de datos es altamente sesgada hacia la falta de videos.
#
# Cantidad de fotos
#
# La variable tiene un rango que va desde un mínimo de 0 (indicando que no hay fotos) hasta un máximo de 30 (indicando un valor extremo de fotos). Esto refleja la variedad en la cantidad de fotos que se incluyen en los perfiles de mascotas.
# Los percentiles y cuartiles muestran que la mayoría de los perfiles de mascotas incluyen al menos algunas fotos, ya que el percentil 5, el primer cuartil (Q1) y la mediana son mayores que 0. El tercer cuartil (Q3) indica que el 75% de los perfiles tienen 5 fotos o menos, y el percentil 95 indica que la gran mayoría de los perfiles tienen 10 fotos o menos.
# La distribución de datos tiende a concentrarse en valores bajos, pero permite un número variable de fotos en algunos perfiles.
#
# *Variables categóricas*
#
# En líneas generales podemos decir que:
#
# El Train_data contiene un 54.2% de perros y un 45.8% de gatos. El mayor porcentaje de dichas mascotas corresponden a el estado de Selampor (58.1%) y Kualu Lumpur (25.6%).
# En relación a caracteristicas físicas, observamos que en relación a la raza principal predomina la "raza mixta" (perro) (39,5%) y "Siberian Husky" (perro) (24.2%)". En menor medida, se encuentra la "doméstica de pelo medio" (gato) (8.4%). El resto de las razas tienen frecuencias menores al 2.5%.
# El health principal de relevancia de las mascotas es el negro (49.5%) y en segundo lugar marrón (25%). El resto de los healthes tienen frecuencias menores al 6.5%.
# La mayoría de las mascotas son hembras (48.5%). El tamaño predominante es el mediano (68.7%) y la healthitud del pelaje es sobresaliente para los pelo corto (58.7%).
# En cuestiones de salud, un 48,2% no cuentan con sus vacunas mientras que un 39.3% si las poseen. Del resto de las mascotas, este dato se desconoce. Así mismo, casi la totalidad de las mascotas (96.6%) son saludables. El 67.2% no ha sido castrada y el 56.2% está deparasitada.
#
# *Variable Target*
#
# Rápidez de adopción
#
# Algunas mascotas (2,7%) son adoptadas inmediatamente. Sin embargo, esto corresponde a la menor proporción de los datos.
# Podría pensarse que ciertas personas están interesadas en adoptar cualquier mascota, o simplemente la mascota tuvo la "suerte" de ser adoptada.
#
# En términos generales, se puede observar que las mascotas suelen ser adoptadas después de haber estado disponibles en la plataforma durante al menos 8 días.

# %% [markdown]
# ### Análisis Bivariado
#
# A continuación, se presenta un análisis descriptivo de cada variable en relación con la velocidad de adopción. Esto nos permitirá identificar posibles patrones de comportamiento que influyen en la adoptabilidad de las mascotas y, a su vez, determinar cuáles características tienen una mayor relación o relevancia en el valor que deseamos predecir.

# %% [markdown]
# * **Velocidad de adopción vs tipo de mascota**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Establecer el tamaño de fuente deseado para el gráfico
sns.set(font_scale=1.2)  # Ajusta el valor según tus preferencias

# Crear un diccionario de mapeo para asignar nombres a las categorías de 'Type'
type_mapping = {1: 'Perro', 2: 'Gato'}  # Agrega los nombres deseados aquí

# Crear una nueva columna 'Type_Name' en el DataFrame con los nombres asignados
train_data['Type_Name'] = train_data['Type'].map(type_mapping)

# Calcular las frecuencias porcentuales para cada categoría
total_counts = train_data['Type_Name'].count()
value_counts = train_data['Type_Name'].value_counts()
percentages = (value_counts / total_counts) * 100

# Gráfico de barras comparativo para AdoptionSpeed vs Type con nombres personalizados
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=train_data, x='Type_Name', hue='AdoptionSpeed')
plt.title('Comparación de Velocidad de adopción por Tipo de mascota', fontsize=16)  # Establecer el tamaño de fuente del título

# Cambiar el tamaño de fuente para las etiquetas 'Perro' y 'Gato'
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)

# Agregar la fuente debajo del eje x
plt.xlabel('Tipo de mascota', fontsize=14)  # Establecer el tamaño de fuente del eje x

# Agregar los porcentajes arriba de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height / total_counts * 100:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Texto de fuente a la izquierda y debajo del eje x
plt.text(-0.1, -0.20, 'Fuente: Kaggle (2018) - Elaboración propia', fontsize=10, ha='left', va='center', transform=ax.transAxes)

plt.ylabel('Cantidad', fontsize=14)  # Establecer el tamaño de fuente del eje y
legend = ax.legend(title='Velocidad de Adopción',title_fontsize=10, fontsize=5)  # Cambiar el tamaño de la leyenda

plt.show()

# %% [markdown]
# Como se puede observar, una vez que los anuncios de adopción se publican en la plataforma, el mayor porcentaje de perros encuentra su nuevo hogar después de un período que supera los 100 días.
#
# Por otro lado, los gatos muestran un patrón de adopción más rápido, generalmente dentro de un rango de 8 a 30 días. Esta diferencia temporal podría sugerir que, en promedio, los gatos son adoptados más rápidamente en comparación con los perros.
#
# Debemos destacar que, al analizar las categorías de velocidad de adopción, encontramos similitudes sorprendentes para ambas mascotas. Esto podría indicar la existencia de factores más complejos y diversos que influyen en la adopción de mascotas, además del tipo de animal.
#
# Como obsevamos en el análisis univariado previo, la base de datos contiene una proporción mayor de perros en comparación con gatos. Esta discrepancia en la representación de ambas mascotas en el conjunto de datos podría también tener un impacto en los patrones de adopción.

# %% [markdown]
# * **Velocidad de adopción vs Género de la mascota**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Establecer el tamaño de fuente deseado para el gráfico
sns.set(font_scale=1.2)  # Ajusta el valor según tus preferencias

# Crear un diccionario de mapeo para asignar nombres a las categorías de 'Type'
gender_mapping = {1: 'Macho', 2: 'Hembra', 3: 'Mixto' } # Agrega los nombres deseados aquí

# Crear una nueva columna 'Type_Name' en el DataFrame con los nombres asignados
train_data['gender_Name'] = train_data['Gender'].map(gender_mapping)

# Calcular las frecuencias porcentuales para cada categoría
total_counts = train_data['gender_Name'].count()
value_counts = train_data['gender_Name'].value_counts()
percentages = (value_counts / total_counts) * 100

# Gráfico de barras comparativo para AdoptionSpeed vs Type con nombres personalizados
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=train_data, x='gender_Name', hue='AdoptionSpeed')
plt.title('Comparación de Velocidad de adopción por Género de mascota', fontsize=16)  # Establecer el tamaño de fuente del título

# Cambiar el tamaño de fuente para las etiquetas de género
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)

# Agregar la fuente debajo del eje x
plt.xlabel('Género', fontsize=14)  # Establecer el tamaño de fuente del eje x

# Agregar los porcentajes arriba de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height / total_counts * 100:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Texto de fuente a la izquierda y debajo del eje x
plt.text(-0.1, -0.20, 'Fuente: Kaggle (2018) - Elaboración propia', fontsize=10, ha='left', va='center', transform=ax.transAxes)

plt.ylabel('Cantidad', fontsize=14)  # Establecer el tamaño de fuente del eje y
legend = ax.legend(title='Velocidad de Adopción',title_fontsize=10, fontsize=5)  # Cambiar el tamaño de la leyenda

plt.show()

# %% [markdown]
# Es evidente que existe una mayor proporción de hembras en el conjunto de datos, y, en general, se observa que las adopciones de hembras tienden a ocurrir después de un período de más de 100 días desde que se publican los anuncios en la plataforma. Sin embargo, estos resultados sugieren que el sexo no tiene una incidencia clara en la velocidad de adopción, ya que se aprecia una similitud en el comportamiento entre las diferentes categorías analizadas.

# %% [markdown]
# * **Velocidad de adopción vs Tamaño de la mascota**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Establecer el tamaño de fuente deseado para el gráfico
sns.set(font_scale=1.2)  # Ajusta el valor según tus preferencias

# Crear un diccionario de mapeo para asignar nombres a las categorías 
tamaño_mapping = {1:'Pequeño', 2:'Mediano', 3:'Grande', 4:'Extra Grande', 0:'No Especificado' } # Agrega los nombres deseados aquí

# Crear una nueva columna 'Type_Name' en el DataFrame con los nombres asignados
train_data['tamaño_Name'] = train_data['MaturitySize'].map(tamaño_mapping)

# Calcular las frecuencias porcentuales para cada categoría
total_counts = train_data['tamaño_Name'].count()
value_counts = train_data['tamaño_Name'].value_counts()
percentages = (value_counts / total_counts) * 100

# Gráfico de barras comparativo para AdoptionSpeed vs Type con nombres personalizados
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=train_data, x='tamaño_Name', hue='AdoptionSpeed')
plt.title('Comparación de Velocidad de adopción por Tamaño de mascota', fontsize=16)  # Establecer el tamaño de fuente del título

# Cambiar el tamaño de fuente para las etiquetas de género
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)

# Agregar la fuente debajo del eje x
plt.xlabel('Tamaño', fontsize=14)  # Establecer el tamaño de fuente del eje x

# Agregar los porcentajes arriba de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height / total_counts * 100:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Texto de fuente a la izquierda y debajo del eje x
plt.text(-0.1, -0.20, 'Fuente: Kaggle (2018) - Elaboración propia', fontsize=10, ha='left', va='center', transform=ax.transAxes)

plt.ylabel('Cantidad', fontsize=14)  # Establecer el tamaño de fuente del eje y
legend = ax.legend(title='Velocidad de Adopción',title_fontsize=10, fontsize=5)  # Cambiar el tamaño de la leyenda

plt.show()

# %% [markdown]
# Al analizar la gráfica, se puede apreciar que los animales de tamaño mediano tienen una representación significativamente mayor en la base de datos, y la mayoría de ellos son adoptados después de transcurrir más de 100 días desde su inclusión en la lista. Es importante destacar que el tipo de animal "extragrande" no muestra una participación relevante en la base de datos, lo que sugiere que este tipo de mascotas es menos común en el conjunto de datos y, en consecuencia, tiene una menor presencia en los procesos de adopción.

# %% [markdown]
# * **Velocidad de adopción vs Longitud de pelaje**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Establecer el tamaño de fuente deseado para el gráfico
sns.set(font_scale=1.2)  # Ajusta el valor según tus preferencias

# Crear un diccionario de mapeo para asignar nombres a las categorías de 'Type'
long_mapping = {1: 'Corto', 2: 'Medio', 3: 'Largo', 4:'No especificado'} # Agrega los nombres deseados aquí

# Crear una nueva columna 'Type_Name' en el DataFrame con los nombres asignados
train_data['long_Name'] = train_data['FurLength'].map(long_mapping)

# Calcular las frecuencias porcentuales para cada categoría
total_counts = train_data['long_Name'].count()
value_counts = train_data['long_Name'].value_counts()
percentages = (value_counts / total_counts) * 100

# Gráfico de barras comparativo para AdoptionSpeed vs Type con nombres personalizados
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=train_data, x='long_Name', hue='AdoptionSpeed')
plt.title('Comparación de Velocidad de adopción por longitud de pelaje', fontsize=16)  # Establecer el tamaño de fuente del título

# Cambiar el tamaño de fuente para las etiquetas de género
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)

# Agregar la fuente debajo del eje x
plt.xlabel('longitud de Pelaje', fontsize=14)  # Establecer el tamaño de fuente del eje x

# Agregar los porcentajes arriba de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height / total_counts * 100:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Texto de fuente a la izquierda y debajo del eje x
plt.text(-0.1, -0.20, 'Fuente: Kaggle (2018) - Elaboración propia', fontsize=10, ha='left', va='center', transform=ax.transAxes)

plt.ylabel('Cantidad', fontsize=14)  # Establecer el tamaño de fuente del eje y
legend = ax.legend(title='Velocidad de Adopción',title_fontsize=10, fontsize=5)  # Cambiar el tamaño de la leyenda

plt.show()

# %% [markdown]
# Se puede observar que dentro de los datos incluídos, las mascotas de pelaje corto predominan en comparación con las demás categorías. A pesar de ello, mayoría de  son adoptadas después de haber estado publicadas durante más de 100 días.
#
# Podemos decir que el tipo de pelaje no tiene un efecto determinante en la velocidad de adopción, ya que, a pesar de la predominancia de mascotas de pelaje corto, en algunos casos, dichas mascotas requieren de un período prolongado de tiempo hasta ser adoptadas.

# %% [markdown]
# **haría un grafico que combine tipo de mascota, pelaje y rapidez de adopción**

# %% [markdown]
# * **Velocidad de adopción vs color principal de la mascota**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Establecer el tamaño de fuente deseado para el gráfico
sns.set(font_scale=1.2)  # Ajusta el valor según tus preferencias

# Crear un diccionario de mapeo para asignar nombres a las categorías de 'Type'
color_mapping = {1: 'Negro', 2: 'Marron', 3: 'Dorado', 4: 'Amarillo', 5: 'Crema', 6: 'Gris', 7: 'Blanco'}  # Agrega los nombres deseados aquí

# Calcular las frecuencias porcentuales para cada categoría
total_counts = train_data['color_Name'].count()
value_counts = train_data['color_Name'].value_counts()
percentages = (value_counts / total_counts) * 100

# Crear una lista de categorías de color
color_categories = list(color_mapping.values())

# Calcular el número de filas y columnas para los gráficos
num_rows = len(color_categories) // 2  # Dos gráficos por fila
if len(color_categories) % 2 != 0:
    num_rows += 1  # Agregar una fila adicional si hay un número impar de categorías

# Crear una cuadrícula de subtramas con el número correcto de filas y columnas
fig, axes = plt.subplots(num_rows, 2, figsize=(12, 12))  # Ajusta el tamaño de la figura según tus preferencias

# Iterar a través de las categorías de color y crear un gráfico para cada una
for i, color in enumerate(color_categories):
    row = i // 2  # Calcular el número de fila actual
    col = i % 2   # Calcular la columna actual (0 o 1)
    ax = axes[row, col]  # Seleccionar la subtrama actual

    # Filtrar el DataFrame para la categoría de color actual
    filtered_data = train_data[train_data['color_Name'] == color]

    # Crear el gráfico de barras para la categoría de color actual
    sns.countplot(data=filtered_data, x='color_Name', hue='AdoptionSpeed', ax=ax)
    ax.set_title(f'{color} - Velocidad de adopción', fontsize=12)  # Establecer el título de la subtrama
    ax.set_xlabel('')  # Eliminar la etiqueta del eje x
    ax.set_ylabel('Cantidad', fontsize=10)  # Establecer el tamaño de fuente del eje y
    ax.legend(title='Velocidad de Adopción', title_fontsize=8, fontsize=6)  # Cambiar el tamaño de la leyenda
    ax.set_ylim(0, 2500)  # Ajustar el rango del eje y según tus datos
    ax.set_xticks([])  # Eliminar las etiquetas de ticks en el eje x

    # Agregar etiquetas de porcentaje centradas en las barras
    for p in ax.patches:
        height = p.get_height()
        ax.annotate(f'{height / len(filtered_data) * 100:.1f}%', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    # Ajustar la separación entre las barras
    ax.margins(x=0.1)

# Eliminar subtramas vacías (si hay un número impar de categorías)
if len(color_categories) % 2 != 0:
    fig.delaxes(axes[num_rows - 1, 1])

# Ajustar la posición vertical de la fuente
plt.subplots_adjust(bottom=0.2)  # Ajusta el valor según tus preferencias

# Agregar la fuente debajo de la cuadrícula de subtramas
plt.text(0.5, -0.15, 'Fuente: Kaggle (2018) - Elaboración propia', fontsize=10, ha='center', va='center', transform=fig.transFigure)

plt.show()

# %% [markdown]
# Cuando se analiza la relación entre el color del pelaje  de las mascotas y su velocidad de adopción podems observar en la gráfica, que el color predominante es el negro.
#
# Además, se puede apreciar que las mascotas de color negro son adoptadas con mayor frecuencia en las categorías 2 y 4 de velocidad de adopción.
#
# Esto quiere decir que, estas adopciones tienden a ocurrir principalmente en dos momentos específicos: entre los 8 y 30 días después de su inclusión en la lista de adopción y después de haber transcurrido más de 100 días. Este patrón revela que el color negro es una característica común entre las mascotas en el conjunto de datos y que la velocidad de adopción se concentra en estos dos intervalos de tiempo.

# %% [markdown]
# * **Velocidad de adopción vs Condiciones de Salud**

# %%
# velocidad de adopción vs esterilizado
import seaborn as sns
import matplotlib.pyplot as plt

# Establecer el tamaño de fuente deseado para el gráfico
sns.set(font_scale=1.2)  # Ajusta el valor según tus preferencias

# Crear un diccionario de mapeo para asignar nombres a las categorías
est_mapping = {1:'Sí', 2:'No', 3:'No Estoy Seguro' }   # Agrega los nombres deseados aquí

# Crear una nueva columna 'Type_Name' en el DataFrame con los nombres asignados
train_data['est_Name'] = train_data['Sterilized'].map(est_mapping)

# Calcular las frecuencias porcentuales para cada categoría
total_counts = train_data['est_Name'].count()
value_counts = train_data['est_Name'].value_counts()
percentages = (value_counts / total_counts) * 100

# Gráfico de barras comparativo para AdoptionSpeed vs Type con nombres personalizados
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=train_data, x='est_Name', hue='AdoptionSpeed')
plt.title('Comparación de Velocidad de adopción por Esterilizado', fontsize=16)  # Establecer el tamaño de fuente del título

# Cambiar el tamaño de fuente para las etiquetas de género
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)

# Agregar la fuente debajo del eje x
plt.xlabel('Esterilizado', fontsize=14)  # Establecer el tamaño de fuente del eje x

# Agregar los porcentajes arriba de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height / total_counts * 100:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Texto de fuente a la izquierda y debajo del eje x
plt.text(-0.1, -0.20, 'Fuente: Kaggle (2018) - Elaboración propia', fontsize=10, ha='left', va='center', transform=ax.transAxes)

plt.ylabel('Cantidad', fontsize=14)  # Establecer el tamaño de fuente del eje y
legend = ax.legend(title='Velocidad de Adopción',title_fontsize=10, fontsize=5)  # Cambiar el tamaño de la leyenda

plt.show()


# velocidad de adopción vs  desparacitado

import seaborn as sns
import matplotlib.pyplot as plt

# Establecer el tamaño de fuente deseado para el gráfico
sns.set(font_scale=1.2)  # Ajusta el valor según tus preferencias

# Crear un diccionario de mapeo para asignar nombres a las categorías
desp_mapping = {1:'Sí', 2:'No', 3:'No Estoy Seguro' }   # Agrega los nombres deseados aquí

# Crear una nueva columna 'Type_Name' en el DataFrame con los nombres asignados
train_data['desp_Name'] = train_data['Sterilized'].map(desp_mapping)

# Calcular las frecuencias porcentuales para cada categoría
total_counts = train_data['desp_Name'].count()
value_counts = train_data['desp_Name'].value_counts()
percentages = (value_counts / total_counts) * 100

# Gráfico de barras comparativo para AdoptionSpeed vs Type con nombres personalizados
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=train_data, x='desp_Name', hue='AdoptionSpeed')
plt.title('Comparación de Velocidad de adopción por Desparacitado', fontsize=16)  # Establecer el tamaño de fuente del título

# Cambiar el tamaño de fuente para las etiquetas de género
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)

# Agregar la fuente debajo del eje x
plt.xlabel('Desparacitado', fontsize=14)  # Establecer el tamaño de fuente del eje x

# Agregar los porcentajes arriba de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height / total_counts * 100:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Texto de fuente a la izquierda y debajo del eje x
plt.text(-0.1, -0.20, 'Fuente: Kaggle (2018) - Elaboración propia', fontsize=10, ha='left', va='center', transform=ax.transAxes)

plt.ylabel('Cantidad', fontsize=14)  # Establecer el tamaño de fuente del eje y
legend = ax.legend(title='Velocidad de Adopción',title_fontsize=10, fontsize=5)  # Cambiar el tamaño de la leyenda

plt.show()



# velocidad de adopci+pn vs vacunado

import seaborn as sns
import matplotlib.pyplot as plt

# Establecer el tamaño de fuente deseado para el gráfico
sns.set(font_scale=1.2)  # Ajusta el valor según tus preferencias

# Crear un diccionario de mapeo para asignar nombres a las categorías
vac_mapping = {1:'Sí', 2:'No', 3:'No Estoy Seguro' }   # Agrega los nombres deseados aquí

# Crear una nueva columna 'Type_Name' en el DataFrame con los nombres asignados
train_data['vac_Name'] = train_data['Vaccinated'].map(vac_mapping)

# Calcular las frecuencias porcentuales para cada categoría
total_counts = train_data['vac_Name'].count()
value_counts = train_data['vac_Name'].value_counts()
percentages = (value_counts / total_counts) * 100

# Gráfico de barras comparativo para AdoptionSpeed vs Type con nombres personalizados
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=train_data, x='vac_Name', hue='AdoptionSpeed')
plt.title('Comparación de Velocidad de adopción por Vacunado', fontsize=16)  # Establecer el tamaño de fuente del título

# Cambiar el tamaño de fuente para las etiquetas de género
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)

# Agregar la fuente debajo del eje x
plt.xlabel('Vacunado', fontsize=14)  # Establecer el tamaño de fuente del eje x

# Agregar los porcentajes arriba de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height / total_counts * 100:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Texto de fuente a la izquierda y debajo del eje x
plt.text(-0.1, -0.20, 'Fuente: Kaggle (2018) - Elaboración propia', fontsize=10, ha='left', va='center', transform=ax.transAxes)

plt.ylabel('Cantidad', fontsize=14)  # Establecer el tamaño de fuente del eje y
legend = ax.legend(title='Velocidad de Adopción',title_fontsize=10, fontsize=5)  # Cambiar el tamaño de la leyenda

plt.show()


#velocidad de adopción vs Salud

import seaborn as sns
import matplotlib.pyplot as plt

# Establecer el tamaño de fuente deseado para el gráfico
sns.set(font_scale=1.2)  # Ajusta el valor según tus preferencias

# Crear un diccionario de mapeo para asignar nombres a las categorías de 'Type'
health_mapping = {1:'Saludable', 2:'Lesión Menor', 3:'Lesión Grave', 0:'No Especificado' }  # Agrega los nombres deseados aquí

# Crear una nueva columna 'Type_Name' en el DataFrame con los nombres asignados
train_data['health_Name'] = train_data['Health'].map(health_mapping)

# Calcular las frecuencias porcentuales para cada categoría
total_counts = train_data['health_Name'].count()
value_counts = train_data['health_Name'].value_counts()
percentages = (value_counts / total_counts) * 100

# Gráfico de barras comparativo para AdoptionSpeed vs Type con nombres personalizados
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=train_data, x='health_Name', hue='AdoptionSpeed')
plt.title('Comparación de Velocidad de adopción por Condiciones de Salud', fontsize=16)  # Establecer el tamaño de fuente del título

# Cambiar el tamaño de fuente para las etiquetas de género
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)

# Agregar la fuente debajo del eje x
plt.xlabel('Condiciones deSalud', fontsize=14)  # Establecer el tamaño de fuente del eje x

# Agregar los porcentajes arriba de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height / total_counts * 100:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Texto de fuente a la izquierda y debajo del eje x
plt.text(-0.1, -0.20, 'Fuente: Kaggle (2018) - Elaboración propia', fontsize=10, ha='left', va='center', transform=ax.transAxes)

plt.ylabel('Cantidad', fontsize=14)  # Establecer el tamaño de fuente del eje y
legend = ax.legend(title='Velocidad de Adopción',title_fontsize=10, fontsize=5)  # Cambiar el tamaño de la leyenda

plt.show()

# %% [markdown]
# #hay que redactar
# De acuerdo con lo que podemos observar en las  gráficas, se puede deducir que existe una preferencia por adoptar mascotas que no han sido esterilizadas. Esto podría sugerir que las personas tienen un interés en tener crías  en lugar de animales esterilizados.
#
# Asimismo, la mayoría de estas mascotas son adoptadas durante el primer mes después de su inclusión en la lista de adopción, lo que indica una rápida respuesta por parte de los adoptantes en estos casos.
#
# Vemos también que existe una propensión a adoptar mascotas que han sido desparasitadas y que han estado en la lista de adopción durante un período que oscila entre los 30 y 100 días. Esta particularidad sugiere que las mascotas que han recibido atención médica y cuidado durante su tiempo en la plataforma tienen una buena acogida por parte de los adoptantes.
#
# Estos patrones pueden ofrecer información valiosa para comprender las preferencias de los potenciales adoptantes y cómo ciertas prácticas de cuidado, como la esterilización y la desparasitación, pueden influir en la velocidad y éxito de las adopciones.
#
# Observamos que existe cierta preferencia por parte de los adoptantes hacia mascotas que aún no han recibido sus vacunas. Estas mascotas suelen encontrar un hogar después de haber permanecido en la lista de adopción durante 30 días.
#
# También, se observa una tendencia a adoptar a las mascotas que se encuentran en buen estado de salud y que han estado disponibles para adopción entre un mes y menos de 90 días.
#
# Es muy importante la información sobre el estado de salud de la mascota, dado que su falta se traduce en una probabilidad considerablemente más alta de no ser adoptada. Por otro lado, las mascotas que se encuentran en un estado de salud óptimo, han sido desparasitadas y no han sido esterilizadas, tienden a ser adoptadas con mayor rapidez. Estos hallazgos sugieren que el conocimiento sobre el estado de salud y las prácticas de cuidado pueden influir significativamente en el proceso de adopción.
#
#
#
# #aca lo que estaba
#
# Se podría decir que las personas prefieren mascotas sin esterilizar, quizás porque desean tener cachorros o gatos pequeños. Además, la mayoría de estas mascotas se adoptan en el primer mes de incluirlos en la lista de adopción. También, es importante mencionar que se adoptan fácilmente las mascotas desparasitadas que llevan en lista entre 30 y 100 días.
#
# Además, las personas prefieren adoptar mascotas no vacunadas. Estas mascotas se adoptan después de estar un mes en la lista de adopción. Igualmente, se dan en adopción los animales que están sanos y que llevan entre un mes y menos de 90 días en la lista. Aunque la mayoría de las mascotas están sanas.
#
# Finalmente, es importante mencionar que cuando no se tiene información sobre el estado de salud de la mascota, la probabilidad de no ser adoptado es mucho más alta, y cuando se tienen mascotas sanas, desparasitadas y no esterilizadas tienden a ser adoptadas más rápido

# %% [markdown]
# ############ hasta aca llegueeeee############
# ##############################################
# ############################################

# %% [markdown]
# de acá para abajo es codigo sucio hay que ver que sirve--no mirar

# %%
#NO CORRE

import pandas as pd
from bokeh.plotting import figure, show
from bokeh.palettes import Category10
from bokeh.transform import dodge

# Supongamos que tienes un DataFrame llamado 'df' con las columnas 'AdoptionSpeed' y 'Type'

# Agrupar y contar las frecuencias de 'AdoptionSpeed' por 'Type'
data_grouped = train_data.groupby(['Type', 'AdoptionSpeed']).size().reset_index(name='counts')

# Crear la figura Bokeh
p = figure(x_range=Category10[5], height=350, title="Comparación de AdoptionSpeed por Type",
           toolbar_location=None, tools="")

# Crear gráficos de barras apiladas para cada nivel de 'Type'
p.vbar(x=dodge('AdoptionSpeed', -0.25, range=p.x_range), top='counts', width=0.4, source=data_grouped,
       line_health='white', fill_health='AdoptionSpeed', legend_field='Type')

# Configurar el gráfico
p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_health = None

# Configurar la leyenda
p.legend.title = "Type"


# Mostrar el gráfico
show(p)

# %% [markdown]
# la gente prefiere las mascotas no vacunadas.

# %%
 # adoptionspeed vs esterilizado

est_mapping = {1:'Sí', 2:'No', 3:'No Estoy Seguro' }  # Agrega los nombres deseados aquí

# Crear una nueva columna 'Type_Name' en el DataFrame con los nombres asignados
train_data['est_Name'] = train_data['Sterilized'].map(est_mapping)

# Gráfico de barras comparativo para AdoptionSpeed vs salud con nombres personalizados
plt.figure(figsize=(10, 6))
sns.countplot(data=train_data, x='est_Name', hue='AdoptionSpeed')
plt.title('Comparación de Velocidad de adopción por Esterilización')
plt.xlabel('Esterilización')
plt.ylabel('Conteo')
plt.legend(title='Velocidad de Adopción')

# %% [markdown]
# La gente también prefiere las mascotas no esterilizadas. Tal vez quieran cachorros/gatitos, o no estén de acuerdo con la esterilización para comodidad de los dueños de mascotas.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Carga tus datos (reemplaza 'df' con tu DataFrame)
# df = ...

# Gráfico de barras comparativo para AdoptionSpeed vs Type
plt.figure(figsize=(10, 6))
sns.countplot(data=train_data, x='Type', hue='AdoptionSpeed')
plt.title('Comparación de AdoptionSpeed por Type')
plt.xlabel('Type')
plt.ylabel('Conteo')
plt.legend(title='AdoptionSpeed')

plt.show()

# %% [markdown]
# ## Etapa 2: Utilizo la información disponible de Train, metadata de imágenes y sentimientos

# %% [markdown]
# ## Primer analisis:
#
# Cargo el dataset completo y para el ID **0a0e8c15b** cargo las imagenes que tiene, metadata de las imagenes y analisis de sentimiento de la descripcion.

# %%
#No ejecutar
# Cargar CSV train de carpeta data/train/train.csv
bandera = False
if bandera:
    train_data = pd.read_csv('../data/train/train.csv', index_col='PetID')
    train_image_1 = cv2.imread('../data/train_images/0a0e8c15b-1.jpg')
    train_image_2 = cv2.imread('../data/train_images/0a0e8c15b-2.jpg')
    with open('../data/train_metadata/0a0e8c15b-1.json', 'r') as archivo:
        # Carga el contenido del archivo JSON en un diccionario
        train_metadata_1 = json.load(archivo)
    with open('../data/train_metadata/0a0e8c15b-2.json', 'r') as archivo:
        # Carga el contenido del archivo JSON en un diccionario
        train_metadata_2 = json.load(archivo)
    with open('../data/train_sentiment/0a0e8c15b.json', 'r') as archivo:
        # Carga el contenido del archivo JSON en un diccionario
        train_sentiment = json.load(archivo)

# %% [markdown]
# Creo una funcion para importar los archivos json a una lista. Los archivos los modelo y los inserto en una lista.

# %%
def getModel(model, listFileFullPath):
    '''model = clase del modelo que se quiere cargar (objeto)
    listFullPath = ruta completa de los archivos a cargar (List[string])
    '''
    #f_train_metadata = glob.glob('../data/train_metadata/*.json')
    #f_train_sentiments = glob.glob('../data/train_sentiment/*.json')

    listObject = []
    for file in listFileFullPath:
        
        file_json = None
        objectModel = None
        
        try:
            with open(file, 'r', encoding='utf-8') as archivo:  # Especifica la codificación utf-8 o la que corresponda
               file_json = json.load(archivo)
        except UnicodeDecodeError as e:
            print(f"Error de decodificación en el archivo '{file}': {e}")
            continue  # Continúa con el siguiente archivo en caso de error
        
        #print(file)
        
        #with open(file, 'r') as archivo:
           #file_json = json.load(archivo)    

        fileName = file.split('/')[-1]
        file_json['fileName'] = fileName
        file_json['PetID'] = fileName.split('.')[0].split('-')[0]
        objectModel = model.Model(**file_json)
        listObject.append(objectModel)

    return listObject

# %%
train_data = pd.read_csv('../data/train/train.csv', index_col='PetID')

# %%
variable=glob.glob('../data/train_metadata/*.json')
nueva_variable = [ruta.replace('\\', '/') for ruta in variable]
nueva_variable
 #variable=['../data/train_metadata/0008c5398-1.json',
#  '../data/train_metadata/0008c5398-2.json',
#  '../data/train_metadata/0008c5398-3.json']
list_metadata = getModel(model_metadata, nueva_variable)

# %%
list_metadata
# Out:
# [Model(labelAnnotations=[LabelAnnotation(mid='/m/01yrx', description='cat', score=0.9943703, topicality=0.9943703), LabelAnnotation(mid='/m/07k6w8', description='small to medium sized cats', score=0.9213904, topicality=0.9213904), LabelAnnotation(mid='/m/01l7qd', description='whiskers', score=0.91749674, topicality=0.91749674), LabelAnnotation(mid='/m/0307l', description='cat like mammal', score=0.89707345, topicality=0.89707345), LabelAnnotation(mid='/m/014sv8', description='eye', score=0.80012083, topicality=0.80012083), LabelAnnotation(mid='/m/07kdjg0', description='khao manee', score=0.7978423, topicality=0.7978423), LabelAnnotation(mid='/m/012c9l', description='domestic short haired cat', score=0.79726064, topicality=0.79726064), LabelAnnotation(mid='/m/0hjzp', description='kitten', score=0.7815977, topicality=0.7815977), LabelAnnotation(mid='/m/04myxc', description='burmilla', score=0.77866554, topicality=0.77866554), LabelAnnotation(mid='/m/05mqq3', description='snout', score=
# ...

# %%
#train_data = pd.read_csv('../data/train/train.csv', index_col='PetID')


f_train_metadata = glob.glob('../data/train_metadata/*.json')
f_train_sentiments = glob.glob('../data/train_sentiment/*.json')

f_train_metadata2 = [ruta.replace('\\', '/') for ruta in f_train_metadata]
list_metadata = getModel(model_metadata, f_train_metadata2)
f_train_sentiments2= [ruta.replace('\\', '/') for ruta in f_train_sentiments]
list_sentiments = getModel(model_sentiment, f_train_sentiments2)

del f_train_metadata2
del f_train_sentiments2

# %% [markdown]
# ## Unifico dataset e informacion extra
#
# En esta seccion vamos a agregar informacion exta al dataset original. Vamos a agregar las siguientes variables:
#
# De la imagen:
#
# 1. Imagen? [SI/NO] Si la mascata tiene imagen 1 sino 0. **(LISTO)**
# 2. ImagenCantidad Cantidad de imagenes que posee la mascota. **(LISTO)**
#
# Del Comentario:
# 1. magnitude. **(LISTO)**
# 2. score. **(LISTO)**
# 3. Cantidad de sentencias. **(LISTO)**
# 4. EntidadCantidad. **(LISTO)**
# 5. Entidad por tipo (son varias columnas). **(PENDIENTE)**
# 6. El nombre de la mascota figura como entidad?. **(PENDIENTE)**
# 7. Idioma. **(PENDIENTE)**
#
# Datos descriptivos: **(PENDIENTE)**
# 1. Agregar Beed
# 2. Agregar health
# 3. Agregar PetFinder
# 4. Agregar state

# %% [markdown]
# ## Creamos funciones para obtener propiedades de los modelos

# %%
# Creo funciones para obtener datos de los modelos. Acá son las vbles que se obtienen del json?

##Sirve para cualquiera de l0s dos modelos
getPetID = lambda x: x.PetID
getPetID_vec = np.vectorize(getPetID)

#Solo para la modelo model_sentiment
#1. magnitude
#2. score
#3. Cantidad de sentencias
#4. EntidadCantidad

getScore = lambda x: x.documentSentiment.score
getScore_vec = np.vectorize(getScore)

getMagnitude = lambda x: x.documentSentiment.magnitude
getMagnitude_vec = np.vectorize(getMagnitude)

getLenEntity = lambda x: len(x.entities)
getLenEntity_vec = np.vectorize(getLenEntity)

getLenSentences = lambda x: len(x.sentences)
getLenSentences_vec = np.vectorize(getLenSentences)

# %% [markdown]
# ## Agregamos variables al dataset original

# %%
#Si tiene o no metadata de la imagen
train_data['Imagen?'] = train_data.index.isin(getPetID_vec(list_metadata))
#Si tiene o no archivo sentiment
train_data['sentiment?'] = train_data.index.isin(getPetID_vec(list_sentiments))

#Busco la cantidad de imagenes y las agrego al DF original
df = pd.DataFrame(getPetID_vec(list_metadata))
df = df[0].value_counts()
df.columns = ['PetID', 'CountImagen']
train_data = train_data.join(df, on='PetID', how='left', lsuffix='_left', rsuffix='_right')
del df

#Agrego informacion de los archivo sentiment
df = pd.DataFrame(
        data = {'Score' : getScore_vec(list_sentiments).tolist()
                ,'Magnitude' : getMagnitude_vec(list_sentiments).tolist()
                ,'CountEntity' : getLenEntity_vec(list_sentiments).tolist()
                ,'CountSentences' : getLenSentences_vec(list_sentiments).tolist()
                }
        , index=getPetID_vec(list_sentiments))

df.index.name = 'PetID'

train_data = train_data.join(df, on='PetID', how='left', lsuffix='_left', rsuffix='_right')
del df

# %% [markdown]
# # EDA

# %%
# Para validar (no ejecutar)
#Buscar archivo por linea de comando
#find . -type f -name "*86e1089a3*"
#find . -type f -name "*1bc0f89d8*"
#1bc0f89d8 
#train_data[train_data['Imagen?'] == False].head(10)
#train_data[train_data['sentiment?'] == True].head(10)
train_data.head(10)
# Out:
#            Type                     Name  Age  Breed1  Breed2  Gender  Color1  \
# PetID
# 86e1089a3     2                   Nibble    3     299       0       1       1
# 6296e909a     2              No Name Yet    1     265       0       1       1
# 3422e4906     1                   Brisco    1     307       0       1       2
# 5842f1ff5     1                     Miko    4     307       0       2       1
# 850a43f90     1                   Hunter    1     307       0       1       1
# d24c30b4b     2                      NaN    3     266       0       2       5
# 1caa6fcdb     2                    BULAT   12     264     264       1       1
# 97aa9eeac     1  Siu Pak & Her 6 Puppies    0     307       0       2       1
# c06d167ca     2                      NaN    2     265       0       2       6
# 7a0942d61     2                    Kitty   12     265       0       2       1
#
#            Color2  Color3  MaturitySize  ...  \
# PetID                                    ...
# ...

# %% [markdown]
# ## Pre-procesar Nulos
#
# Verificar la existencia de Nulos y decidir como Imputarlos en caso de que existan
#
# Verificar la existencia de Ceros u otros valores que puedan indicar que pueden ser perdidos

# %% [markdown]
# ### Nulos

# %%
#Verificar la existencia de Nulos en train_date y decidir como Imputarlos en caso de que existan
rta = train_data.isnull().sum()
#imprimir solo los que tienen nulos
rta[rta > 0]
# Out:
# Name              1265
# Description         13
# count              341
# Score              551
# Magnitude          551
# CountEntity        551
# CountSentences     551
# dtype: int64

# %% [markdown]
# *count es cantidad de imagen
#
# Los nombres tienen null (esto no seria un problema). Por otro lado el resto de las variables que estan null son las variables que generamos desde los archivos, es decir, tienen null porque no poseen archivo para esos PetID.

# %% [markdown]
# ### Ceros

# %%
#Verificar la existencia de ceros en train_date y decidir como Imputarlos en caso de que existan
rta = (train_data == 0).sum()
#imprimir solo los que tienen ceros
rta[rta > 0]
# Out:
# Age                179
# Breed1               5
# Breed2           10762
# Color2            4471
# Color3           10604
# Fee              12663
# VideoAmt         14419
# PhotoAmt           341
# AdoptionSpeed      410
# Imagen?            341
# sentiment?         551
# Score             2328
# Magnitude          596
# CountEntity        273
# dtype: int64

# %% [markdown]
# | Variable|Cantida Cero | Observacion
# | ----------------|-------|--------------
# | Age             |   179 | (Valor posible)
# | Breed1          |     5 | No existe descripcion para estos casos
# | Breed2          | 10762 | No existe descripcion para estos casos
# | health2          |  4471 | No existe descripcion para estos casos
# | health3          | 10604 | No existe descripcion para estos casos
# | Fee             | 12663 | (Valor posible) Fee - Adoption fee (0 = Free)
# | VideoAmt        | 14419 | (Valor posible) Videos subidos para la mascota
# | PhotoAmt        |   341 | (Valor posible) Fotos subidos para la mascota
# | AdoptionSpeed   |   410 | (Valor posible)
# | Imagen?         |   341 | (Valor posible)
# | sentiment?      |   551 | (Valor posible)
# | Score           |  2328 | (Valor posible)
# | Magnitude       |   596 | (Valor posible)
# | CountEntity     |   273 | (Valor posible)

# %%
#graficar la distribucion de la variable a Age y un diagrama de caja y bigotes
#Quiero que el grafico sea animado
#https://towardsdatascience.com/creating-animated-gif-using-python-opencv-31f5bbf27d9c
#https://stackoverflow.com/questions/44947505/how-to-make-a-gif-loop-in-python
#https://stackoverflow.com/questions/753190/programmatically-generate-video-or-animated-gif-in-python   

train_data['Age'].hist(bins=100)
train_data.boxplot(column=['Age'])
# Out:
# <Axes: >

# %%
# generar una tabla resumen de train_data con cantidad de registros, cantidad de requistros que poseen imagen (imagen?) y cantidad de registros que poseen sentimientos (sentiment?)

cantidadRegistros = train_data.shape[0]
print(f'Cantidad de registros: {cantidadRegistros}')
print(f'Cantidad de registros con imagen: {train_data["Imagen?"].sum()}')
print(f'Cantidad de registros sin imagen: {cantidadRegistros - train_data["Imagen?"].sum()}')
print(f'Cantidad de registros con sentimientos: {train_data["sentiment?"].sum()}')
print(f'Cantidad de registros sin sentimientos: {cantidadRegistros - train_data["sentiment?"].sum()}')
# Out:
# Cantidad de registros: 14993
# Cantidad de registros con imagen: 14652
# Cantidad de registros sin imagen: 341
# Cantidad de registros con sentimientos: 14442
# Cantidad de registros sin sentimientos: 551

# %%
#import dtale
#dtale.show(train_data)
#http://localhost:40000/

# %%
#import seaborn.apionly as sns #ya no va mas este llamado. Reemplazo por linea siguiente
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import model_selection
#sns.set() #ya no va mas. Reemplazo por linea siguiente
sns.set_theme()

# %%
#setup para el notebook
# %matplotlib inline
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:,.2f}'.format
plt.rcParams['figure.figsize'] = (16, 12)

# %%
train_data.head()
# Out:
#            Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  \
# PetID
# 86e1089a3     2       Nibble    3     299       0       1       1       7
# 6296e909a     2  No Name Yet    1     265       0       1       1       2
# 3422e4906     1       Brisco    1     307       0       1       2       7
# 5842f1ff5     1         Miko    4     307       0       2       1       2
# 850a43f90     1       Hunter    1     307       0       1       1       0
#
#            Color3  MaturitySize  ...  \
# PetID                            ...
# 86e1089a3       0             1  ...
# 6296e909a       0             2  ...
# 3422e4906       0             2  ...
# 5842f1ff5       0             2  ...
# 850a43f90       0             2  ...
#
#                                                  Description  PhotoAmt  \
# PetID
# 86e1089a3  Nibble is a 3+ month old ball of cuteness. He ...      1.00
# 6296e909a  I just found it alone yesterday near my apartm...      2.00
# ...

# %%
#Detectar columnas categoricas
#Convertir columnas tipo object a categoricas o dato que corresponda
train_data2 = train_data.drop("Description", axis=1)
train_data2 = train_data2.drop("RescuerID", axis=1)
train_data2 = train_data2.drop("Name", axis=1)

#train_data2['AdoptionSpeed'] = pd.Categorical(train_data2['AdoptionSpeed'])
train_data2['Type'] = pd.Categorical(train_data2['Type'])
train_data2['Breed1'] = pd.Categorical(train_data2['Breed1'])
train_data2['Breed2'] = pd.Categorical(train_data2['Breed2'])
train_data2['Gender'] = pd.Categorical(train_data2['Gender'])
train_data2['health1'] = pd.Categorical(train_data2['health1'])
train_data2['health2'] = pd.Categorical(train_data2['health2'])
train_data2['health3'] = pd.Categorical(train_data2['health3'])
train_data2['MaturitySize'] = pd.Categorical(train_data2['MaturitySize'])
train_data2['FurLength'] = pd.Categorical(train_data2['FurLength'])
train_data2['Vaccinated'] = pd.Categorical(train_data2['Vaccinated'])
train_data2['Dewormed'] = pd.Categorical(train_data2['Dewormed'])
train_data2['Sterilized'] = pd.Categorical(train_data2['Sterilized'])
train_data2['Health'] = pd.Categorical(train_data2['Health'])

train_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14993 entries, 86e1089a3 to a83d95ead
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            14993 non-null  category
#  1   Age             14993 non-null  int64
#  2   Breed1          14993 non-null  category
#  3   Breed2          14993 non-null  category
#  4   Gender          14993 non-null  category
#  5   Color1          14993 non-null  category
#  6   Color2          14993 non-null  category
#  7   Color3          14993 non-null  category
#  8   MaturitySize    14993 non-null  category
#  9   FurLength       14993 non-null  category
#  10  Vaccinated      14993 non-null  category
#  11  Dewormed        14993 non-null  category
#  12  Sterilized      14993 non-null  category
#  13  Health          14993 non-null  category
#  14  Quantity        14993 non-null  int64
#  15  Fee             14993 non-null  int64
# ...

# %%
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(train_data2.drop("AdoptionSpeed", axis=1), 
                                                                    train_data2.AdoptionSpeed, test_size=0.1, random_state=0)
print(f"X_train: {X_train.shape}")
print(f"X_valid: {X_valid.shape}")
print(f"y_train: {y_train.shape}")
print(f"y_valid: {y_valid.shape}")
# Out:
# X_train: (13493, 26)
# X_valid: (1500, 26)
# y_train: (13493,)
# y_valid: (1500,)

# %%
from xgboost import XGBClassifier
#import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'max_depth': [4, 6, 8], # Maximum number of levels in tree
    'min_child_weight': [1, 5, 10], # Minimum number of samples required at each leaf node
    'gamma': [0, 0.1, 0.2], # Minimum loss reduction required to ma ke a further partition on a leaf node. The larger gamma is, the more conservative the algorithm will be.
    'n_estimators': [100, 200, 300] # Number of boosting stages to perform
}
categorical_columns = ['Type', 'Breed1', 'Breed2', 'Gender', 'health1', 'health2', 'health3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed', 'Sterilized', 'Health']

# Create a based model
xgb_clf = XGBClassifier(#objective='multi:softmax', 
                            #num_class=len(np.unique(y_train)), 
                            #early_stopping_rounds=10, 
                            enable_categorical=True, categorical_feature=categorical_columns,
                            eval_metric=['merror','mlogloss'], 
                            seed=42)

# Instantiate the grid search model
grid = GridSearchCV(estimator = xgb_clf, param_grid = param_grid,
                          cv = 5, n_jobs = -1, verbose = 2)
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# c:\Users\Maira\Desktop\MAESTRIA\LABO_II\Kaggle\Labo_II\Lib\site-packages\xgboost\data.py:463: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   or is_sparse(dtype)
# c:\Users\Maira\Desktop\MAESTRIA\LABO_II\Kaggle\Labo_II\Lib\site-packages\xgboost\data.py:464: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   or (is_categorical_dtype(dtype) and enable_categorical)
# c:\Users\Maira\Desktop\MAESTRIA\LABO_II\Kaggle\Labo_II\Lib\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# ...
